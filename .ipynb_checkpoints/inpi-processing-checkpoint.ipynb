# %% [markdown]
# Do in shell :
#
# `mkdir tmpzip && mkdir tmp && mkdir data && cd data`
#
# `wget -r --no-parent https://data.cquest.org/inpi_rncs/imr/`
#
# `mkdir data.cquest.org/inpi_rncs/imr/flux`
#
# `mv data.cquest.org/inpi_rncs/imr/20* data.cquest.org/inpi_rncs/imr/flux/`
#
# 2017:
# `for f in *.zip; do mkdir ${f:0:4} && mkdir ${f:0:4}/${f:5:2} && unzip $f -d ${f:0:4}/${f:5:2}/ && rm *.zip && rm *.html; done`
#
# 2018 ok
#
# 2019, 2020, 2021, 2022
# `for f in */*/*.zip; do mkdir ${f:0:2}/${f:3:2}/${f:6:4} && mkdir ${f:0:2}/${f:3:2}/${f:6:4}/${f:11:2} && unzip $f -d ${f:0:2}/${f:3:2}/${f:6:4}/${f:11:2}/; done`
# `rm */*/*.html && rm */*/*.zip && rm */*/*.md5`
#
# On ordonne le tout pour que toutes les données soient dans data/TYPE_DONNEES/ANNEE/MOIS/JOUR/GREFFECODE/GREFFECODE2/DONNEESCSV

# %%
import sqlite3
import shutil
import zipfile
import glob
import unidecode
import os
import py7zr
from datetime import date, timedelta
import pandas as pd
import time
from os.path import exists

# %%
sdate = date(2017,5,4)   # start date
edate = date(2022,3,17)   # end date
list_dates = [x.strftime("%Y-%m-%d") for x in pd.date_range(sdate,edate-timedelta(days=1),freq='d').to_list()]

# %%
vol_data = '/Volumes/OnlyData/inpi/data/'

# %%
def concatFilesRep(type_file, name_concat, pattern):
    pathdate = vol_data + type_file + "/" + ld.split('-')[0] + '/' + ld.split('-')[1] + '/' + ld.split('-')[2] + '/'
    consofile = vol_data + 'synthese/' + ld + name_concat + '.csv'
    # get list files stock
    list_files = glob.glob(pathdate + pattern)
    list_files.sort()
    if len(list_files) > 0:
        
        with open(consofile,"wb") as fout:
            # first file:
            with open(list_files[0], "rb") as f:
                fout.write(f.read())
            # now the rest:    
            for ls in list_files[1:]:
                with open(ls, "rb") as f:
                    try:
                        next(f) # skip the header
                    except:
                        pass
                    fout.write(f.read())
        
        
        #os.system('rm ' + consofile + ' && ulimit -n 10240 && head -n1 ' + list_files[0] + ' > ' + consofile)
        #for ls in list_files:
        #    os.system('tail -n+2 -q ' + ls + ' >> ' + consofile)
        
        print(name_concat + " ok")

# %%
for ld in list_dates[895:]:
    print(ld)
    concatFilesRep("stock", "_stock_rep", "*/*/*_5_rep.csv")
    concatFilesRep("flux-tc", "_flux_rep", "*/*/*_5_rep.csv")
    concatFilesRep("flux-tc", "_flux_rep_nouveau_modifie", "*/*/*6_rep_nouveau_modifie_EVT.csv")
    concatFilesRep("flux-tc", "_flux_rep_partant", "*/*/*7_rep_partant_EVT.csv")
# Out:
# 2019-10-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-20
# 2019-10-21
# _stock_rep ok
# 2019-10-22
# 2019-10-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-27
# 2019-10-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-10-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-03
# 2019-11-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-10
# 2019-11-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-17
# 2019-11-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-24
# 2019-11-25
# _stock_rep ok
# 2019-11-26
# 2019-11-27
# 2019-11-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-11-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-01
# 2019-12-02
# 2019-12-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-08
# 2019-12-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-15
# 2019-12-16
# 2019-12-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-22
# 2019-12-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-29
# 2019-12-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2019-12-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-05
# 2020-01-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-12
# 2020-01-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-19
# 2020-01-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-25
# 2020-01-26
# 2020-01-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-01-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-02
# 2020-02-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-09
# 2020-02-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-16
# 2020-02-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-23
# 2020-02-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-02-29
# 2020-03-01
# 2020-03-02
# 2020-03-03
# _stock_rep ok
# 2020-03-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-08
# 2020-03-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-15
# 2020-03-16
# 2020-03-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-22
# 2020-03-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-29
# 2020-03-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-03-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-05
# 2020-04-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-12
# 2020-04-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-19
# 2020-04-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-25
# 2020-04-26
# 2020-04-27
# 2020-04-28
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-04-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-03
# 2020-05-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-10
# 2020-05-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-17
# 2020-05-18
# 2020-05-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-24
# 2020-05-25
# 2020-05-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-05-31
# 2020-06-01
# 2020-06-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-07
# 2020-06-08
# 2020-06-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-14
# 2020-06-15
# 2020-06-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-21
# 2020-06-22
# 2020-06-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-26
# 2020-06-27
# 2020-06-28
# 2020-06-29
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-06-30
# 2020-07-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-05
# 2020-07-06
# 2020-07-07
# _stock_rep ok
# 2020-07-08
# 2020-07-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-11
# 2020-07-12
# 2020-07-13
# 2020-07-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-19
# 2020-07-20
# 2020-07-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-26
# 2020-07-27
# 2020-07-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-07-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-01
# 2020-08-02
# 2020-08-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-04
# 2020-08-05
# 2020-08-06
# 2020-08-07
# 2020-08-08
# 2020-08-09
# 2020-08-10
# 2020-08-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-16
# 2020-08-17
# 2020-08-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-23
# 2020-08-24
# 2020-08-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-08-30
# 2020-08-31
# 2020-09-01
# 2020-09-02
# 2020-09-03
# 2020-09-04
# 2020-09-05
# 2020-09-06
# 2020-09-07
# 2020-09-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-11
# 2020-09-12
# 2020-09-13
# 2020-09-14
# 2020-09-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-20
# 2020-09-21
# 2020-09-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-27
# 2020-09-28
# 2020-09-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-09-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-02
# 2020-10-03
# 2020-10-04
# 2020-10-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-11
# 2020-10-12
# 2020-10-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-18
# 2020-10-19
# 2020-10-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-25
# 2020-10-26
# 2020-10-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-10-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-01
# 2020-11-02
# 2020-11-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-08
# 2020-11-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-11
# 2020-11-12
# 2020-11-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-15
# 2020-11-16
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-22
# 2020-11-23
# _stock_rep ok
# 2020-11-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-11-29
# 2020-11-30
# _stock_rep ok
# 2020-12-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-03
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-06
# 2020-12-07
# _stock_rep ok
# 2020-12-08
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-09
# 2020-12-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-13
# 2020-12-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-20
# 2020-12-21
# 2020-12-22
# 2020-12-23
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-27
# 2020-12-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2020-12-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-03
# 2021-01-04
# 2021-01-05
# 2021-01-06
# 2021-01-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-10
# 2021-01-11
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-17
# 2021-01-18
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-19
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-24
# 2021-01-25
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-01-31
# 2021-02-01
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-07
# 2021-02-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-14
# 2021-02-15
# 2021-02-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-21
# 2021-02-22
# 2021-02-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-02-28
# 2021-03-01
# 2021-03-02
# _stock_rep ok
# 2021-03-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-07
# 2021-03-08
# 2021-03-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-11
# 2021-03-12
# 2021-03-13
# 2021-03-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-15
# 2021-03-16
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-20
# 2021-03-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-23
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-24
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-28
# 2021-03-29
# _stock_rep ok
# 2021-03-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-03-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-02
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-03
# 2021-04-04
# 2021-04-05
# 2021-04-06
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-12
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-21
# 2021-04-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-26
# 2021-04-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-04-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-03
# 2021-05-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-08
# 2021-05-09
# 2021-05-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-11
# _stock_rep ok
# 2021-05-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-16
# 2021-05-17
# 2021-05-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-23
# 2021-05-24
# 2021-05-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-05-30
# 2021-05-31
# 2021-06-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-06
# 2021-06-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-13
# 2021-06-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-20
# 2021-06-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-27
# 2021-06-28
# 2021-06-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-06-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-04
# 2021-07-05
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-06
# _stock_rep ok
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-11
# 2021-07-12
# 2021-07-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-18
# 2021-07-19
# 2021-07-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-25
# 2021-07-26
# 2021-07-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-07-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-01
# 2021-08-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-08
# 2021-08-09
# 2021-08-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-15
# 2021-08-16
# 2021-08-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-22
# 2021-08-23
# 2021-08-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-08-29
# 2021-08-30
# 2021-08-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-05
# 2021-09-06
# 2021-09-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-12
# 2021-09-13
# 2021-09-14
# _stock_rep ok
# 2021-09-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-19
# 2021-09-20
# 2021-09-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-26
# 2021-09-27
# 2021-09-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-09-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-03
# 2021-10-04
# 2021-10-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-10
# 2021-10-11
# 2021-10-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-17
# 2021-10-18
# 2021-10-19
# 2021-10-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-24
# 2021-10-25
# 2021-10-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-10-31
# 2021-11-01
# 2021-11-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-07
# 2021-11-08
# 2021-11-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-14
# 2021-11-15
# 2021-11-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-20
# 2021-11-21
# 2021-11-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-23
# _stock_rep ok
# 2021-11-24
# _stock_rep ok
# 2021-11-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-11-28
# 2021-11-29
# 2021-11-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-05
# 2021-12-06
# 2021-12-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-12
# 2021-12-13
# _stock_rep ok
# 2021-12-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-19
# 2021-12-20
# 2021-12-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-26
# 2021-12-27
# 2021-12-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-30
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2021-12-31
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-01
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-02
# 2022-01-03
# 2022-01-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-06
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-07
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-09
# 2022-01-10
# 2022-01-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-13
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-16
# 2022-01-17
# 2022-01-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-20
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-21
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-23
# 2022-01-24
# 2022-01-25
# _stock_rep ok
# 2022-01-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-27
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-28
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-29
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-01-30
# 2022-01-31
# 2022-02-01
# _stock_rep ok
# 2022-02-02
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-06
# 2022-02-07
# 2022-02-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-13
# 2022-02-14
# 2022-02-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-17
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-18
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-19
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-20
# 2022-02-21
# 2022-02-22
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-23
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-24
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-25
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-26
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-02-27
# 2022-02-28
# 2022-03-01
# _stock_rep ok
# 2022-03-02
# 2022-03-03
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-04
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-05
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-06
# 2022-03-07
# 2022-03-08
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-09
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-10
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-11
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-12
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-13
# 2022-03-14
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-15
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok
# 2022-03-16
# _flux_rep ok
# _flux_rep_nouveau_modifie ok
# _flux_rep_partant ok

# %%
# !rm inpi.db

# %%
connection = sqlite3.connect('inpi.db')

# %%
cursor = connection.cursor()

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS rep_pp
              (siren TEXT, rep_noms TEXT, rep_prenoms TEXT, rep_qualite)''')

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS rep_pm
              (siren TEXT, rep_denomination TEXT, rep_qualite)''')

# %%
cursor.execute('''CREATE INDEX idx_siren_pp ON rep_pp (siren);''')
cursor.execute('''CREATE INDEX idx_siren_pm ON rep_pm (siren);''')
cursor.execute('''CREATE INDEX idx_noms_pp ON rep_pp (rep_noms);''')
cursor.execute('''CREATE INDEX idx_denomination_pm ON rep_pm (rep_denomination);''')

# %%
connection.commit()

# %%
def uniformizeDf(df):
    for c in df.columns:
        df = df.rename(columns={c: unidecode.unidecode(
                                c.lower() \
                                .replace(' ', '') \
                                .replace('.','') \
                                .replace('_','') \
                                .replace('"','') \
                                .replace("'",'')
                    )})

    # Do something
    df['siren'] = df.fillna('')['siren']
    df['rep_noms'] = df.fillna('')['nompatronymique']
    df.loc[df["nomusage"].notna(), "rep_noms"] = df["nompatronymique"] + ' ' + df['nomusage']
    df['rep_noms'] = df['rep_noms'].apply(lambda x: str(x).replace(',','').lower())
    df['rep_prenoms'] = df.fillna('')['prenoms']
    df['rep_prenoms'] = df['rep_prenoms'].apply(lambda x: str(x).replace(',','').lower())
    df['rep_denomination'] = df.fillna('')['denomination']
    df['rep_qualite'] = df.fillna('')['qualite']
    dfpp = df[df['type'].str.contains('Physique')][['siren','rep_noms','rep_prenoms','rep_qualite']]
    dfpm = df[df['type'].str.contains('Morale')][['siren','rep_denomination','rep_qualite']]

    return dfpp, dfpm

# %%
list_files = glob.glob(vol_data + 'stock/2017/05/04/*/*/*5_rep.csv')
list_files.sort()
for lf in list_files:
    print(lf)
    df = pd.read_csv(lf,sep=";",dtype=str)
    dfpp, dfpm = uniformizeDf(df)
    dfpp.set_index('siren').to_sql('rep_pp', con=connection, if_exists='append')
    dfpm.set_index('siren').to_sql('rep_pm', con=connection, if_exists='append')
# Out:
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0101/S1/0101_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0202/S1/0202_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0203/S1/0203_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0301/S1/0301_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0303/S1/0303_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0401/S1/0401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0501/S1/0501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0601/S1/0601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0602/S1/0602_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0603/S1/0603_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0605/S1/0605_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0702/S1/0702_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0802/S1/0802_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/0901/S1/0901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1001/S1/1001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1101/S1/1101_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1104/S1/1104_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1203/S1/1203_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1301/S1/1301_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1303/S1/1303_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1304/S1/1304_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1305/S1/1305_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1402/S1/1402_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1407/S1/1407_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1501/S1/1501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1601/S1/1601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1704/S1/1704_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1708/S1/1708_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1801/S1/1801_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/1901/S1/1901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2001/S1/2001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2002/S1/2002_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2104/S1/2104_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2202/S1/2202_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2301/S1/2301_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2401/S1/2401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2402/S1/2402_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2501/S1/2501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2602/S1/2602_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2701/S1/2701_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2702/S1/2702_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2801/S1/2801_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2901/S1/2901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/2903/S1/2903_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3003/S1/3003_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3102/S1/3102_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3201/S1/3201_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3302/S1/3302_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3303/S1/3303_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3402/S1/3402_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3405/S1/3405_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3501/S1/3501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3502/S1/3502_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3601/S1/3601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3701/S1/3701_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3801/S1/3801_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3802/S1/3802_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/3902/S1/3902_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4001/S1/4001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4002/S1/4002_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4101/S1/4101_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4201/S1/4201_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4202/S1/4202_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4302/S1/4302_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4401/S1/4401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4402/S1/4402_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4502/S1/4502_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4601/S1/4601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4701/S1/4701_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4801/S1/4801_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/4901/S1/4901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5001/S1/5001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5002/S1/5002_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5101/S1/5101_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5103/S1/5103_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5201/S1/5201_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5301/S1/5301_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5401/S1/5401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5402/S1/5402_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5501/S1/5501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5601/S1/5601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5602/S1/5602_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5802/S1/5802_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5902/S1/5902_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5906/S1/5906_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5910/S1/5910_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/5952/S1/5952_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6001/S1/6001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6002/S1/6002_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6101/S1/6101_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6201/S1/6201_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6202/S1/6202_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6303/S1/6303_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6401/S1/6401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6403/S1/6403_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6502/S1/6502_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6601/S1/6601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6901/S1/6901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/6903/S1/6903_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7001/S1/7001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7102/S1/7102_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7106/S1/7106_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7202/S1/7202_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7301/S1/7301_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7401/S1/7401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7402/S1/7402_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7501/S1/7501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7601/S1/7601_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7606/S1/7606_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7608/S1/7608_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7701/S1/7701_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7702/S1/7702_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7801/S1/7801_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7802/S1/7802_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7803/S1/7803_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/7901/S1/7901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8002/S1/8002_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8101/S1/8101_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8102/S1/8102_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8201/S1/8201_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8302/S1/8302_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8303/S1/8303_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8305/S1/8305_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8401/S1/8401_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8501/S1/8501_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8602/S1/8602_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8701/S1/8701_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8801/S1/8801_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8901/S1/8901_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/8903/S1/8903_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/9001/S1/9001_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/9201/S1/9201_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/9301/S1/9301_S1_20170504_5_rep.csv
# /Volumes/OnlyData/inpi/data/stock/2017/05/04/9401/S1/9401_S1_20170504_5_rep.csv

# %%
original = 'inpi.db'
target = 'inpi-stock-initial.db'
shutil.copyfile(original, target)

# %%
list_dates[698]
# Out:
# '2019-04-02'

# %%
len(list_dates)
# Out:
# 1778

# %%
for ld in list_dates:
    print(ld)
    if ld.split('-')[2] == '01':
        original = 'inpi.db'
        target = 'inpi-'+ld+'.db'
        shutil.copyfile(original, target)
    
    consofile = vol_data + 'synthese/' + ld + '_stock_rep.csv'
    # Manage stocks
    if(os.path.exists(consofile)):
        df = pd.read_csv(consofile,sep=";",dtype=str,on_bad_lines='warn')
        dfpp, dfpm = uniformizeDf(df)
        print('loaded and uniformize')
        # Delete old stock
        if(ld != '2017-05-04'):
            print('Old stock')
            result = 0
            for index,row in dfpp.iterrows():
                del_query = """DELETE from rep_pp where siren = ?"""
                cursor.execute(del_query, (row['siren'],))
                result = result + cursor.rowcount
            connection.commit()
            for index,row in dfpp.iterrows():
                del_query = """DELETE from rep_pm where siren = ?"""
                cursor.execute(del_query, (row['siren'],))
                result = result + cursor.rowcount
            connection.commit()
            print('Old Stock deleted : ' + str(result) + ' deleted records')
        # Add new stock
        dfpp.set_index('siren').to_sql('rep_pp', con=connection, if_exists='append')
        dfpm.set_index('siren').to_sql('rep_pm', con=connection, if_exists='append')
        print('Stock processed : ' + str(dfpp.shape[0]+dfpm.shape[0]) + 'added records')

    
    consofile = vol_data + 'synthese/' + ld + '_flux_rep.csv'
    if(os.path.exists(consofile)):
        df = pd.read_csv(consofile,sep=";",dtype=str,on_bad_lines='warn')
        dfpp, dfpm = uniformizeDf(df)
        dfpp.set_index('siren').to_sql('rep_pp', con=connection, if_exists='append')
        dfpm.set_index('siren').to_sql('rep_pm', con=connection, if_exists='append')
        print('Flux rep processed : ' + str(dfpp.shape[0]+dfpm.shape[0]) + 'added records')

    consofile = vol_data + 'synthese/' + ld + '_flux_rep_nouveau_modifie.csv'
    if(os.path.exists(consofile)):
        df = pd.read_csv(consofile,sep=";",dtype=str,on_bad_lines='warn')
        dfpp, dfpm = uniformizeDf(df)
        dfpp.set_index('siren').to_sql('rep_pp', con=connection, if_exists='append')
        dfpm.set_index('siren').to_sql('rep_pm', con=connection, if_exists='append')
        print('Flux rep modified new processed : ' + str(dfpp.shape[0]+dfpm.shape[0]) + 'added records')

    
    consofile = vol_data + 'synthese/' + ld + '_flux_rep_partant.csv'
    if(os.path.exists(consofile)):
        df = pd.read_csv(consofile,sep=";",dtype=str,on_bad_lines='warn')
        dfpp, dfpm = uniformizeDf(df)
        # Delete each rep
        result = 0
        for index,row in dfpp.iterrows():
            del_query = """DELETE from rep_pp where siren = ? AND rep_noms = ? AND rep_prenoms = ? AND rep_qualite = ?"""
            cursor.execute(del_query, (row['siren'], row['rep_noms'], row['rep_prenoms'], row['rep_qualite']))
            result = result + cursor.rowcount
        connection.commit()
        for index,row in dfpm.iterrows():
            del_query = """DELETE from rep_pm where siren = ? AND rep_denomination = ? AND rep_qualite = ?"""
            cursor.execute(del_query, (row['siren'], row['rep_denomination'], row['rep_qualite']))
            result = result + cursor.rowcount
        connection.commit()
        print('Flux rep partant processed : ' + str(result) + ' deleted records')
# Out:
# 2019-04-01
# Flux rep processed : 24157added records
# Flux rep modified new processed : 16325added records
# Flux rep partant processed : 3900 deleted records
# 2019-04-02
# Flux rep processed : 15085added records
# Flux rep modified new processed : 8729added records
# Flux rep partant processed : 1868 deleted records
# 2019-04-03
# Flux rep processed : 11062added records
# Flux rep modified new processed : 6616added records
# Flux rep partant processed : 1292 deleted records
# 2019-04-04
# Flux rep processed : 16341added records
# Flux rep modified new processed : 6079added records
# Flux rep partant processed : 1239 deleted records
# 2019-04-05
# Flux rep processed : 10172added records
# Flux rep modified new processed : 7228added records
# Flux rep partant processed : 2018 deleted records
# 2019-04-06
# Flux rep processed : 9188added records
# Flux rep modified new processed : 5400added records
# Flux rep partant processed : 1052 deleted records
# 2019-04-07
# 2019-04-08
# Flux rep processed : 1204added records
# Flux rep modified new processed : 499added records
# Flux rep partant processed : 228 deleted records
# 2019-04-09
# Flux rep processed : 9941added records
# Flux rep modified new processed : 6557added records
# Flux rep partant processed : 1401 deleted records
# 2019-04-10
# Flux rep processed : 9735added records
# Flux rep modified new processed : 5955added records
# Flux rep partant processed : 1481 deleted records
# 2019-04-11
# Flux rep processed : 9375added records
# Flux rep modified new processed : 5309added records
# Flux rep partant processed : 1310 deleted records
# 2019-04-12
# Flux rep processed : 10589added records
# Flux rep modified new processed : 6103added records
# Flux rep partant processed : 1403 deleted records
# 2019-04-13
# Flux rep processed : 9070added records
# Flux rep modified new processed : 5059added records
# Flux rep partant processed : 1054 deleted records
# 2019-04-14
# 2019-04-15
# Flux rep processed : 384added records
# Flux rep modified new processed : 333added records
# Flux rep partant processed : 181 deleted records
# 2019-04-16
# Flux rep processed : 9638added records
# Flux rep modified new processed : 6154added records
# Flux rep partant processed : 1360 deleted records
# 2019-04-17
# Flux rep processed : 6206added records
# Flux rep modified new processed : 2873added records
# Flux rep partant processed : 758 deleted records
# 2019-04-18
# Flux rep processed : 12420added records
# Flux rep modified new processed : 7307added records
# Flux rep partant processed : 1512 deleted records
# 2019-04-19
# Flux rep processed : 5031added records
# Flux rep modified new processed : 3071added records
# Flux rep partant processed : 751 deleted records
# 2019-04-20
# Flux rep processed : 12773added records
# Flux rep modified new processed : 6740added records
# Flux rep partant processed : 1340 deleted records
# 2019-04-21
# 2019-04-22
# 2019-04-23
# Flux rep processed : 1277added records
# Flux rep modified new processed : 323added records
# Flux rep partant processed : 46 deleted records
# 2019-04-24
# Flux rep processed : 12011added records
# Flux rep modified new processed : 7323added records
# Flux rep partant processed : 1903 deleted records
# 2019-04-25
# Flux rep processed : 1398added records
# Flux rep modified new processed : 815added records
# Flux rep partant processed : 334 deleted records
# 2019-04-26
# Flux rep processed : 14844added records
# Flux rep modified new processed : 11116added records
# Flux rep partant processed : 2129 deleted records
# 2019-04-27
# Flux rep processed : 8145added records
# Flux rep modified new processed : 4980added records
# Flux rep partant processed : 960 deleted records
# 2019-04-28
# 2019-04-29
# Flux rep processed : 420added records
# Flux rep modified new processed : 261added records
# Flux rep partant processed : 93 deleted records
# 2019-04-30
# Flux rep processed : 10198added records
# Flux rep modified new processed : 6317added records
# Flux rep partant processed : 1305 deleted records
# 2019-05-01
# Flux rep processed : 9221added records
# Flux rep modified new processed : 5764added records
# Flux rep partant processed : 1145 deleted records
# 2019-05-02
# Flux rep processed : 1155added records
# Flux rep modified new processed : 504added records
# Flux rep partant processed : 190 deleted records
# 2019-05-03
# Flux rep processed : 11010added records
# Flux rep modified new processed : 7005added records
# Flux rep partant processed : 1323 deleted records
# 2019-05-04
# Flux rep processed : 7970added records
# Flux rep modified new processed : 5691added records
# Flux rep partant processed : 1125 deleted records
# 2019-05-05
# 2019-05-06
# loaded and uniformize
# Old stock
# Old Stock deleted : 780884 deleted records
# Stock processed : 502966added records
# Flux rep processed : 341added records
# Flux rep modified new processed : 324added records
# Flux rep partant processed : 173 deleted records
# 2019-05-07
# Flux rep processed : 10598added records
# Flux rep modified new processed : 6130added records
# Flux rep partant processed : 1229 deleted records
# 2019-05-08
# Flux rep processed : 9721added records
# Flux rep modified new processed : 5908added records
# Flux rep partant processed : 1218 deleted records
# 2019-05-09
# Flux rep processed : 201added records
# Flux rep modified new processed : 247added records
# Flux rep partant processed : 133 deleted records
# 2019-05-10
# Flux rep processed : 11477added records
# Flux rep modified new processed : 6569added records
# Flux rep partant processed : 1351 deleted records
# 2019-05-11
# Flux rep processed : 7552added records
# Flux rep modified new processed : 5286added records
# Flux rep partant processed : 1088 deleted records
# 2019-05-12
# 2019-05-13
# Flux rep processed : 347added records
# Flux rep modified new processed : 389added records
# Flux rep partant processed : 180 deleted records
# 2019-05-14
# Flux rep processed : 12614added records
# Flux rep modified new processed : 7496added records
# Flux rep partant processed : 1378 deleted records
# 2019-05-15
# Flux rep processed : 6154added records
# Flux rep modified new processed : 3920added records
# Flux rep partant processed : 1062 deleted records
# 2019-05-16
# Flux rep processed : 11740added records
# Flux rep modified new processed : 8873added records
# Flux rep partant processed : 1918 deleted records
# 2019-05-17
# Flux rep processed : 10262added records
# Flux rep modified new processed : 6432added records
# Flux rep partant processed : 1397 deleted records
# 2019-05-18
# Flux rep processed : 5869added records
# Flux rep modified new processed : 3161added records
# Flux rep partant processed : 822 deleted records
# 2019-05-19
# 2019-05-20
# 2019-05-21
# Flux rep processed : 5892added records
# Flux rep modified new processed : 3347added records
# Flux rep partant processed : 633 deleted records
# 2019-05-22
# Flux rep processed : 24326added records
# Flux rep modified new processed : 15021added records
# Flux rep partant processed : 2613 deleted records
# 2019-05-23
# Flux rep processed : 14083added records
# Flux rep modified new processed : 7032added records
# Flux rep partant processed : 1469 deleted records
# 2019-05-24
# Flux rep processed : 11829added records
# Flux rep modified new processed : 7141added records
# Flux rep partant processed : 1323 deleted records
# 2019-05-25
# Flux rep processed : 5565added records
# Flux rep modified new processed : 3379added records
# Flux rep partant processed : 723 deleted records
# 2019-05-26
# 2019-05-27
# Flux rep processed : 402added records
# Flux rep modified new processed : 283added records
# Flux rep partant processed : 166 deleted records
# 2019-05-28
# Flux rep processed : 14215added records
# Flux rep modified new processed : 8637added records
# Flux rep partant processed : 1679 deleted records
# 2019-05-29
# Flux rep processed : 9347added records
# Flux rep modified new processed : 5877added records
# Flux rep partant processed : 1439 deleted records
# 2019-05-30
# Flux rep processed : 9360added records
# Flux rep modified new processed : 5393added records
# Flux rep partant processed : 1056 deleted records
# 2019-05-31
# 2019-06-01
# Flux rep processed : 4346added records
# Flux rep modified new processed : 1963added records
# Flux rep partant processed : 471 deleted records
# 2019-06-02
# 2019-06-03
# Flux rep processed : 199added records
# Flux rep modified new processed : 334added records
# Flux rep partant processed : 184 deleted records
# 2019-06-04
# Flux rep processed : 14412added records
# Flux rep modified new processed : 7281added records
# Flux rep partant processed : 1410 deleted records
# 2019-06-05
# Flux rep processed : 26058added records
# Flux rep modified new processed : 6285added records
# Flux rep partant processed : 1287 deleted records
# 2019-06-06
# Flux rep processed : 10458added records
# Flux rep modified new processed : 5318added records
# Flux rep partant processed : 1352 deleted records
# 2019-06-07
# Flux rep processed : 8218added records
# Flux rep modified new processed : 6116added records
# Flux rep partant processed : 1042 deleted records
# 2019-06-08
# Flux rep processed : 9249added records
# Flux rep modified new processed : 4754added records
# Flux rep partant processed : 1121 deleted records
# 2019-06-09
# 2019-06-10
# 2019-06-11
# Flux rep processed : 3429added records
# Flux rep modified new processed : 1434added records
# Flux rep partant processed : 464 deleted records
# 2019-06-12
# Flux rep processed : 9205added records
# Flux rep modified new processed : 5851added records
# Flux rep partant processed : 1088 deleted records
# 2019-06-13
# Flux rep processed : 5815added records
# Flux rep modified new processed : 3647added records
# Flux rep partant processed : 1031 deleted records
# 2019-06-14
# Flux rep processed : 12087added records
# Flux rep modified new processed : 8003added records
# Flux rep partant processed : 1690 deleted records
# 2019-06-15
# Flux rep processed : 9117added records
# Flux rep modified new processed : 5285added records
# Flux rep partant processed : 1354 deleted records
# 2019-06-16
# 2019-06-17
# 2019-06-18
# loaded and uniformize
# Old stock
# Old Stock deleted : 75175 deleted records
# Stock processed : 43644added records
# 2019-06-19
# Flux rep processed : 13594added records
# Flux rep modified new processed : 10708added records
# Flux rep partant processed : 2740 deleted records
# 2019-06-20
# Flux rep processed : 11102added records
# Flux rep modified new processed : 8619added records
# Flux rep partant processed : 2035 deleted records
# 2019-06-21
# Flux rep processed : 6800added records
# Flux rep modified new processed : 6443added records
# Flux rep partant processed : 1643 deleted records
# 2019-06-22
# Flux rep processed : 3812added records
# Flux rep modified new processed : 3261added records
# Flux rep partant processed : 790 deleted records
# 2019-06-23
# 2019-06-24
# Flux rep processed : 392added records
# Flux rep modified new processed : 381added records
# Flux rep partant processed : 241 deleted records
# 2019-06-25
# Flux rep processed : 9382added records
# Flux rep modified new processed : 8507added records
# Flux rep partant processed : 2044 deleted records
# 2019-06-26
# Flux rep processed : 6281added records
# Flux rep modified new processed : 6128added records
# Flux rep partant processed : 1578 deleted records
# 2019-06-27
# Flux rep processed : 3686added records
# Flux rep modified new processed : 3669added records
# Flux rep partant processed : 854 deleted records
# 2019-06-28
# Flux rep processed : 7325added records
# Flux rep modified new processed : 7431added records
# Flux rep partant processed : 2003 deleted records
# 2019-06-29
# Flux rep processed : 6152added records
# Flux rep modified new processed : 5699added records
# Flux rep partant processed : 1435 deleted records
# 2019-06-30
# 2019-07-01
# Flux rep processed : 352added records
# Flux rep modified new processed : 339added records
# Flux rep partant processed : 190 deleted records
# 2019-07-02
# Flux rep processed : 6093added records
# Flux rep modified new processed : 6181added records
# Flux rep partant processed : 1533 deleted records
# 2019-07-03
# Flux rep processed : 6037added records
# Flux rep modified new processed : 6889added records
# Flux rep partant processed : 1964 deleted records
# 2019-07-04
# Flux rep processed : 5377added records
# Flux rep modified new processed : 6230added records
# Flux rep partant processed : 1499 deleted records
# 2019-07-05
# Flux rep processed : 5908added records
# Flux rep modified new processed : 6485added records
# Flux rep partant processed : 1801 deleted records
# 2019-07-06
# Flux rep processed : 4384added records
# Flux rep modified new processed : 4635added records
# Flux rep partant processed : 1237 deleted records
# 2019-07-07
# 2019-07-08
# Flux rep processed : 316added records
# Flux rep modified new processed : 707added records
# Flux rep partant processed : 384 deleted records
# 2019-07-09
# Flux rep processed : 6433added records
# Flux rep modified new processed : 7133added records
# Flux rep partant processed : 1824 deleted records
# 2019-07-10
# Flux rep processed : 5353added records
# Flux rep modified new processed : 6595added records
# Flux rep partant processed : 1698 deleted records
# 2019-07-11
# Flux rep processed : 6557added records
# Flux rep modified new processed : 7247added records
# Flux rep partant processed : 2025 deleted records
# 2019-07-12
# Flux rep processed : 730added records
# Flux rep modified new processed : 1270added records
# Flux rep partant processed : 519 deleted records
# 2019-07-13
# Flux rep processed : 8002added records
# Flux rep modified new processed : 8378added records
# Flux rep partant processed : 2073 deleted records
# 2019-07-14
# 2019-07-15
# Flux rep processed : 396added records
# Flux rep modified new processed : 734added records
# Flux rep partant processed : 373 deleted records
# 2019-07-16
# Flux rep processed : 8317added records
# Flux rep modified new processed : 7822added records
# Flux rep partant processed : 2217 deleted records
# 2019-07-17
# Flux rep processed : 4509added records
# Flux rep modified new processed : 5682added records
# Flux rep partant processed : 1646 deleted records
# 2019-07-18
# Flux rep processed : 6453added records
# Flux rep modified new processed : 7073added records
# Flux rep partant processed : 1971 deleted records
# 2019-07-19
# Flux rep processed : 5615added records
# Flux rep modified new processed : 4232added records
# Flux rep partant processed : 1295 deleted records
# 2019-07-20
# Flux rep processed : 10682added records
# Flux rep modified new processed : 6662added records
# Flux rep partant processed : 1931 deleted records
# 2019-07-21
# 2019-07-22
# Flux rep processed : 341added records
# Flux rep modified new processed : 805added records
# Flux rep partant processed : 436 deleted records
# 2019-07-23
# Flux rep processed : 5459added records
# Flux rep modified new processed : 4792added records
# Flux rep partant processed : 1454 deleted records
# 2019-07-24
# Flux rep processed : 5220added records
# Flux rep modified new processed : 6293added records
# Flux rep partant processed : 1772 deleted records
# 2019-07-25
# Flux rep processed : 8472added records
# Flux rep modified new processed : 7875added records
# Flux rep partant processed : 2608 deleted records
# 2019-07-26
# Flux rep processed : 4318added records
# Flux rep modified new processed : 4182added records
# Flux rep partant processed : 1594 deleted records
# 2019-07-27
# Flux rep processed : 6961added records
# Flux rep modified new processed : 6461added records
# Flux rep partant processed : 1730 deleted records
# 2019-07-28
# 2019-07-29
# Flux rep processed : 407added records
# Flux rep modified new processed : 925added records
# Flux rep partant processed : 453 deleted records
# 2019-07-30
# Flux rep processed : 6245added records
# Flux rep modified new processed : 6385added records
# Flux rep partant processed : 1918 deleted records
# 2019-07-31
# Flux rep processed : 5515added records
# Flux rep modified new processed : 6472added records
# Flux rep partant processed : 2100 deleted records
# 2019-08-01
# Flux rep processed : 3927added records
# Flux rep modified new processed : 4492added records
# Flux rep partant processed : 1608 deleted records
# 2019-08-02
# Flux rep processed : 7052added records
# Flux rep modified new processed : 8398added records
# Flux rep partant processed : 2311 deleted records
# 2019-08-03
# Flux rep processed : 4820added records
# Flux rep modified new processed : 5389added records
# Flux rep partant processed : 1445 deleted records
# 2019-08-04
# 2019-08-05
# 2019-08-06
# Flux rep processed : 5034added records
# Flux rep modified new processed : 5148added records
# Flux rep partant processed : 1401 deleted records
# 2019-08-07
# Flux rep processed : 4430added records
# Flux rep modified new processed : 5615added records
# Flux rep partant processed : 1643 deleted records
# 2019-08-08
# Flux rep processed : 4311added records
# Flux rep modified new processed : 5327added records
# Flux rep partant processed : 1226 deleted records
# 2019-08-09
# 2019-08-10
# Flux rep processed : 4449added records
# Flux rep modified new processed : 5443added records
# Flux rep partant processed : 1505 deleted records
# 2019-08-11
# 2019-08-12
# 2019-08-13
# Flux rep processed : 6886added records
# Flux rep modified new processed : 12144added records
# Flux rep partant processed : 4766 deleted records
# 2019-08-14
# Flux rep processed : 3300added records
# Flux rep modified new processed : 3696added records
# Flux rep partant processed : 1282 deleted records
# 2019-08-15
# Flux rep processed : 4330added records
# Flux rep modified new processed : 6403added records
# Flux rep partant processed : 1731 deleted records
# 2019-08-16
# Flux rep processed : 254added records
# Flux rep modified new processed : 588added records
# Flux rep partant processed : 247 deleted records
# 2019-08-17
# Flux rep processed : 2133added records
# Flux rep modified new processed : 3489added records
# Flux rep partant processed : 812 deleted records
# 2019-08-18
# 2019-08-19
# Flux rep processed : 67added records
# Flux rep modified new processed : 536added records
# Flux rep partant processed : 318 deleted records
# 2019-08-20
# Flux rep processed : 2864added records
# Flux rep modified new processed : 4967added records
# Flux rep partant processed : 1519 deleted records
# 2019-08-21
# Flux rep processed : 3300added records
# Flux rep modified new processed : 4271added records
# Flux rep partant processed : 1425 deleted records
# 2019-08-22
# Flux rep processed : 3103added records
# Flux rep modified new processed : 4537added records
# Flux rep partant processed : 1305 deleted records
# 2019-08-23
# Flux rep processed : 3314added records
# Flux rep modified new processed : 5009added records
# Flux rep partant processed : 1515 deleted records
# 2019-08-24
# Flux rep processed : 2797added records
# Flux rep modified new processed : 3575added records
# Flux rep partant processed : 865 deleted records
# 2019-08-25
# 2019-08-26
# Flux rep processed : 58added records
# Flux rep modified new processed : 386added records
# Flux rep partant processed : 198 deleted records
# 2019-08-27
# Flux rep processed : 2888added records
# Flux rep modified new processed : 5449added records
# Flux rep partant processed : 1574 deleted records
# 2019-08-28
# Flux rep processed : 2931added records
# Flux rep modified new processed : 4917added records
# Flux rep partant processed : 1392 deleted records
# 2019-08-29
# Flux rep processed : 3826added records
# Flux rep modified new processed : 4753added records
# Flux rep partant processed : 1321 deleted records
# 2019-08-30
# Flux rep processed : 3531added records
# Flux rep modified new processed : 4785added records
# Flux rep partant processed : 1421 deleted records
# 2019-08-31
# Flux rep processed : 3064added records
# Flux rep modified new processed : 3953added records
# Flux rep partant processed : 1184 deleted records
# 2019-09-01
# 2019-09-02
# Flux rep processed : 207added records
# Flux rep modified new processed : 477added records
# Flux rep partant processed : 218 deleted records
# 2019-09-03
# Flux rep processed : 3709added records
# Flux rep modified new processed : 5030added records
# Flux rep partant processed : 1457 deleted records
# 2019-09-04
# Flux rep processed : 4173added records
# Flux rep modified new processed : 5584added records
# Flux rep partant processed : 1686 deleted records
# 2019-09-05
# Flux rep processed : 4376added records
# Flux rep modified new processed : 5356added records
# Flux rep partant processed : 1588 deleted records
# 2019-09-06
# Flux rep processed : 4059added records
# Flux rep modified new processed : 5648added records
# Flux rep partant processed : 1716 deleted records
# 2019-09-07
# Flux rep processed : 3625added records
# Flux rep modified new processed : 4431added records
# Flux rep partant processed : 1118 deleted records
# 2019-09-08
# 2019-09-09
# Flux rep processed : 143added records
# Flux rep modified new processed : 658added records
# Flux rep partant processed : 286 deleted records
# 2019-09-10
# Flux rep processed : 5030added records
# Flux rep modified new processed : 6178added records
# Flux rep partant processed : 2064 deleted records
# 2019-09-11
# Flux rep processed : 4696added records
# Flux rep modified new processed : 5608added records
# Flux rep partant processed : 1851 deleted records
# 2019-09-12
# Flux rep processed : 3933added records
# Flux rep modified new processed : 5403added records
# Flux rep partant processed : 1736 deleted records
# 2019-09-13
# Flux rep processed : 4584added records
# Flux rep modified new processed : 5904added records
# Flux rep partant processed : 1685 deleted records
# 2019-09-14
# Flux rep processed : 3701added records
# Flux rep modified new processed : 4659added records
# Flux rep partant processed : 1221 deleted records
# 2019-09-15
# 2019-09-16
# Flux rep processed : 324added records
# Flux rep modified new processed : 777added records
# Flux rep partant processed : 396 deleted records
# 2019-09-17
# Flux rep processed : 3458added records
# Flux rep modified new processed : 6165added records
# Flux rep partant processed : 2023 deleted records
# 2019-09-18
# Flux rep processed : 4027added records
# Flux rep modified new processed : 6240added records
# Flux rep partant processed : 2015 deleted records
# 2019-09-19
# Flux rep processed : 4912added records
# Flux rep modified new processed : 5364added records
# Flux rep partant processed : 1518 deleted records
# 2019-09-20
# Flux rep processed : 4242added records
# Flux rep modified new processed : 3947added records
# Flux rep partant processed : 1205 deleted records
# 2019-09-21
# Flux rep processed : 5980added records
# Flux rep modified new processed : 7201added records
# Flux rep partant processed : 1849 deleted records
# 2019-09-22
# 2019-09-23
# loaded and uniformize
# Old stock
# Old Stock deleted : 116632 deleted records
# Stock processed : 68935added records
# 2019-09-24
# 2019-09-25
# Flux rep processed : 2267added records
# Flux rep modified new processed : 3221added records
# Flux rep partant processed : 1205 deleted records
# 2019-09-26
# Flux rep processed : 717added records
# Flux rep modified new processed : 1386added records
# Flux rep partant processed : 440 deleted records
# 2019-09-27
# Flux rep processed : 740added records
# Flux rep modified new processed : 1285added records
# Flux rep partant processed : 461 deleted records
# 2019-09-28
# Flux rep processed : 388added records
# Flux rep modified new processed : 634added records
# Flux rep partant processed : 137 deleted records
# 2019-09-29
# 2019-09-30
# Flux rep processed : 234added records
# Flux rep modified new processed : 533added records
# Flux rep partant processed : 236 deleted records
# 2019-10-01
# Flux rep processed : 28545added records
# Flux rep modified new processed : 27933added records
# Flux rep partant processed : 7785 deleted records
# 2019-10-02
# Flux rep processed : 4436added records
# Flux rep modified new processed : 6215added records
# Flux rep partant processed : 1859 deleted records
# 2019-10-03
# Flux rep processed : 4267added records
# Flux rep modified new processed : 5369added records
# Flux rep partant processed : 1588 deleted records
# 2019-10-04
# Flux rep processed : 356added records
# Flux rep modified new processed : 705added records
# Flux rep partant processed : 331 deleted records
# 2019-10-05
# Flux rep processed : 868added records
# Flux rep modified new processed : 1278added records
# Flux rep partant processed : 317 deleted records
# 2019-10-06
# 2019-10-07
# Flux rep processed : 354added records
# Flux rep modified new processed : 649added records
# Flux rep partant processed : 297 deleted records
# 2019-10-08
# Flux rep processed : 11553added records
# Flux rep modified new processed : 13447added records
# Flux rep partant processed : 3367 deleted records
# 2019-10-09
# Flux rep processed : 5550added records
# Flux rep modified new processed : 7641added records
# Flux rep partant processed : 2260 deleted records
# 2019-10-10
# Flux rep processed : 4402added records
# Flux rep modified new processed : 6101added records
# Flux rep partant processed : 1536 deleted records
# 2019-10-11
# Flux rep processed : 4352added records
# Flux rep modified new processed : 5733added records
# Flux rep partant processed : 1555 deleted records
# 2019-10-12
# Flux rep processed : 4498added records
# Flux rep modified new processed : 4604added records
# Flux rep partant processed : 1265 deleted records
# 2019-10-13
# 2019-10-14
# Flux rep processed : 281added records
# Flux rep modified new processed : 757added records
# Flux rep partant processed : 377 deleted records
# 2019-10-15
# Flux rep processed : 4627added records
# Flux rep modified new processed : 6028added records
# Flux rep partant processed : 1858 deleted records
# 2019-10-16
# Flux rep processed : 4523added records
# Flux rep modified new processed : 6345added records
# Flux rep partant processed : 1768 deleted records
# 2019-10-17
# Flux rep processed : 4937added records
# Flux rep modified new processed : 6600added records
# Flux rep partant processed : 1806 deleted records
# 2019-10-18
# Flux rep processed : 5177added records
# Flux rep modified new processed : 5910added records
# Flux rep partant processed : 1718 deleted records
# 2019-10-19
# Flux rep processed : 3866added records
# Flux rep modified new processed : 4758added records
# Flux rep partant processed : 1299 deleted records
# 2019-10-20
# 2019-10-21
# loaded and uniformize
# Old stock
# Old Stock deleted : 51960 deleted records
# Stock processed : 49607added records
# 2019-10-22
# 2019-10-23
# Flux rep processed : 10062added records
# Flux rep modified new processed : 14148added records
# Flux rep partant processed : 4022 deleted records
# 2019-10-24
# Flux rep processed : 4152added records
# Flux rep modified new processed : 6175added records
# Flux rep partant processed : 2043 deleted records
# 2019-10-25
# Flux rep processed : 4152added records
# Flux rep modified new processed : 5352added records
# Flux rep partant processed : 1598 deleted records
# 2019-10-26
# Flux rep processed : 4927added records
# Flux rep modified new processed : 4852added records
# Flux rep partant processed : 1430 deleted records
# 2019-10-27
# 2019-10-28
# Flux rep processed : 450added records
# Flux rep modified new processed : 803added records
# Flux rep partant processed : 364 deleted records
# 2019-10-29
# Flux rep processed : 3520added records
# Flux rep modified new processed : 4299added records
# Flux rep partant processed : 1269 deleted records
# 2019-10-30
# Flux rep processed : 6088added records
# Flux rep modified new processed : 7702added records
# Flux rep partant processed : 2206 deleted records
# 2019-10-31
# Flux rep processed : 4101added records
# Flux rep modified new processed : 5738added records
# Flux rep partant processed : 1832 deleted records
# 2019-11-01
# Flux rep processed : 3880added records
# Flux rep modified new processed : 4618added records
# Flux rep partant processed : 1150 deleted records
# 2019-11-02
# Flux rep processed : 591added records
# Flux rep modified new processed : 147added records
# Flux rep partant processed : 29 deleted records
# 2019-11-03
# 2019-11-04
# Flux rep processed : 153added records
# Flux rep modified new processed : 598added records
# Flux rep partant processed : 274 deleted records
# 2019-11-05
# Flux rep processed : 3941added records
# Flux rep modified new processed : 4305added records
# Flux rep partant processed : 1258 deleted records
# 2019-11-06
# Flux rep processed : 4320added records
# Flux rep modified new processed : 5975added records
# Flux rep partant processed : 1448 deleted records
# 2019-11-07
# Flux rep processed : 6951added records
# Flux rep modified new processed : 6703added records
# Flux rep partant processed : 1751 deleted records
# 2019-11-08
# Flux rep processed : 4723added records
# Flux rep modified new processed : 3823added records
# Flux rep partant processed : 1076 deleted records
# 2019-11-09
# Flux rep processed : 3264added records
# Flux rep modified new processed : 5037added records
# Flux rep partant processed : 1358 deleted records
# 2019-11-10
# 2019-11-11
# Flux rep processed : 122added records
# Flux rep modified new processed : 0added records
# Flux rep partant processed : 0 deleted records
# 2019-11-12
# Flux rep processed : 2147added records
# Flux rep modified new processed : 2056added records
# Flux rep partant processed : 653 deleted records
# 2019-11-13
# Flux rep processed : 340added records
# Flux rep modified new processed : 571added records
# Flux rep partant processed : 269 deleted records
# 2019-11-14
# Flux rep processed : 2663added records
# Flux rep modified new processed : 4193added records
# Flux rep partant processed : 1058 deleted records
# 2019-11-15
# Flux rep processed : 8839added records
# Flux rep modified new processed : 9965added records
# Flux rep partant processed : 2657 deleted records
# 2019-11-16
# Flux rep processed : 3065added records
# Flux rep modified new processed : 3675added records
# Flux rep partant processed : 937 deleted records
# 2019-11-17
# 2019-11-18
# Flux rep processed : 403added records
# Flux rep modified new processed : 703added records
# Flux rep partant processed : 230 deleted records
# 2019-11-19
# Flux rep processed : 6881added records
# Flux rep modified new processed : 8733added records
# Flux rep partant processed : 2385 deleted records
# 2019-11-20
# Flux rep processed : 4949added records
# Flux rep modified new processed : 5726added records
# Flux rep partant processed : 1742 deleted records
# 2019-11-21
# Flux rep processed : 5292added records
# Flux rep modified new processed : 5634added records
# Flux rep partant processed : 1446 deleted records
# 2019-11-22
# Flux rep processed : 4550added records
# Flux rep modified new processed : 5620added records
# Flux rep partant processed : 1688 deleted records
# 2019-11-23
# Flux rep processed : 3726added records
# Flux rep modified new processed : 4928added records
# Flux rep partant processed : 1113 deleted records
# 2019-11-24
# 2019-11-25
# loaded and uniformize
# Old stock
# Old Stock deleted : 107019 deleted records
# Stock processed : 64650added records
# 2019-11-26
# 2019-11-27
# 2019-11-28
# Flux rep processed : 13594added records
# Flux rep modified new processed : 17753added records
# Flux rep partant processed : 5189 deleted records
# 2019-11-29
# Flux rep processed : 5000added records
# Flux rep modified new processed : 5172added records
# Flux rep partant processed : 1581 deleted records
# 2019-11-30
# Flux rep processed : 1184added records
# Flux rep modified new processed : 1687added records
# Flux rep partant processed : 465 deleted records
# 2019-12-01
# 2019-12-02
# 2019-12-03
# Flux rep processed : 5453added records
# Flux rep modified new processed : 8123added records
# Flux rep partant processed : 2038 deleted records
# 2019-12-04
# Flux rep processed : 4754added records
# Flux rep modified new processed : 8816added records
# Flux rep partant processed : 2704 deleted records
# 2019-12-05
# Flux rep processed : 6861added records
# Flux rep modified new processed : 5132added records
# Flux rep partant processed : 1536 deleted records
# 2019-12-06
# Flux rep processed : 5301added records
# Flux rep modified new processed : 6466added records
# Flux rep partant processed : 2015 deleted records
# 2019-12-07
# Flux rep processed : 3250added records
# Flux rep modified new processed : 4997added records
# Flux rep partant processed : 1222 deleted records
# 2019-12-08
# 2019-12-09
# Flux rep processed : 694added records
# Flux rep modified new processed : 784added records
# Flux rep partant processed : 405 deleted records
# 2019-12-10
# Flux rep processed : 5940added records
# Flux rep modified new processed : 5288added records
# Flux rep partant processed : 1697 deleted records
# 2019-12-11
# Flux rep processed : 7376added records
# Flux rep modified new processed : 8375added records
# Flux rep partant processed : 2066 deleted records
# 2019-12-12
# Flux rep processed : 3455added records
# Flux rep modified new processed : 5175added records
# Flux rep partant processed : 1346 deleted records
# 2019-12-13
# Flux rep processed : 6546added records
# Flux rep modified new processed : 6648added records
# Flux rep partant processed : 1819 deleted records
# 2019-12-14
# Flux rep processed : 4101added records
# Flux rep modified new processed : 4576added records
# Flux rep partant processed : 1194 deleted records
# 2019-12-15
# 2019-12-16
# 2019-12-17
# Flux rep processed : 7533added records
# Flux rep modified new processed : 6835added records
# Flux rep partant processed : 2094 deleted records
# 2019-12-18
# Flux rep processed : 3817added records
# Flux rep modified new processed : 4597added records
# Flux rep partant processed : 1165 deleted records
# 2019-12-19
# Flux rep processed : 361added records
# Flux rep modified new processed : 699added records
# Flux rep partant processed : 320 deleted records
# 2019-12-20
# Flux rep processed : 10435added records
# Flux rep modified new processed : 12242added records
# Flux rep partant processed : 3360 deleted records
# 2019-12-21
# Flux rep processed : 5153added records
# Flux rep modified new processed : 5069added records
# Flux rep partant processed : 1450 deleted records
# 2019-12-22
# 2019-12-23
# Flux rep processed : 413added records
# Flux rep modified new processed : 548added records
# Flux rep partant processed : 150 deleted records
# 2019-12-24
# Flux rep processed : 5334added records
# Flux rep modified new processed : 5335added records
# Flux rep partant processed : 1487 deleted records
# 2019-12-25
# Flux rep processed : 3929added records
# Flux rep modified new processed : 3778added records
# Flux rep partant processed : 978 deleted records
# 2019-12-26
# Flux rep processed : 493added records
# Flux rep modified new processed : 494added records
# Flux rep partant processed : 171 deleted records
# 2019-12-27
# Flux rep processed : 3785added records
# Flux rep modified new processed : 4074added records
# Flux rep partant processed : 1093 deleted records
# 2019-12-28
# Flux rep processed : 3190added records
# Flux rep modified new processed : 3907added records
# Flux rep partant processed : 982 deleted records
# 2019-12-29
# 2019-12-30
# Flux rep processed : 290added records
# Flux rep modified new processed : 441added records
# Flux rep partant processed : 148 deleted records
# 2019-12-31
# Flux rep processed : 3940added records
# Flux rep modified new processed : 4709added records
# Flux rep partant processed : 1183 deleted records
# 2020-01-01
# Flux rep processed : 2453added records
# Flux rep modified new processed : 3123added records
# Flux rep partant processed : 664 deleted records
# 2020-01-02
# Flux rep processed : 514added records
# Flux rep modified new processed : 950added records
# Flux rep partant processed : 286 deleted records
# 2020-01-03
# Flux rep processed : 2645added records
# Flux rep modified new processed : 3922added records
# Flux rep partant processed : 1247 deleted records
# 2020-01-04
# Flux rep processed : 2387added records
# Flux rep modified new processed : 3367added records
# Flux rep partant processed : 946 deleted records
# 2020-01-05
# 2020-01-06
# Flux rep processed : 46added records
# Flux rep modified new processed : 615added records
# Flux rep partant processed : 311 deleted records
# 2020-01-07
# Flux rep processed : 3013added records
# Flux rep modified new processed : 5627added records
# Flux rep partant processed : 1530 deleted records
# 2020-01-08
# Flux rep processed : 3381added records
# Flux rep modified new processed : 3924added records
# Flux rep partant processed : 1179 deleted records
# 2020-01-09
# Flux rep processed : 5630added records
# Flux rep modified new processed : 6865added records
# Flux rep partant processed : 1915 deleted records
# 2020-01-10
# Flux rep processed : 4333added records
# Flux rep modified new processed : 5450added records
# Flux rep partant processed : 1559 deleted records
# 2020-01-11
# Flux rep processed : 3867added records
# Flux rep modified new processed : 4264added records
# Flux rep partant processed : 1190 deleted records
# 2020-01-12
# 2020-01-13
# Flux rep processed : 325added records
# Flux rep modified new processed : 575added records
# Flux rep partant processed : 279 deleted records
# 2020-01-14
# Flux rep processed : 4639added records
# Flux rep modified new processed : 5920added records
# Flux rep partant processed : 1532 deleted records
# 2020-01-15
# Flux rep processed : 4568added records
# Flux rep modified new processed : 6113added records
# Flux rep partant processed : 1806 deleted records
# 2020-01-16
# Flux rep processed : 6836added records
# Flux rep modified new processed : 4671added records
# Flux rep partant processed : 1334 deleted records
# 2020-01-17
# Flux rep processed : 4888added records
# Flux rep modified new processed : 6949added records
# Flux rep partant processed : 2198 deleted records
# 2020-01-18
# Flux rep processed : 5232added records
# Flux rep modified new processed : 5515added records
# Flux rep partant processed : 1311 deleted records
# 2020-01-19
# 2020-01-20
# Flux rep processed : 341added records
# Flux rep modified new processed : 751added records
# Flux rep partant processed : 312 deleted records
# 2020-01-21
# Flux rep processed : 3866added records
# Flux rep modified new processed : 5238added records
# Flux rep partant processed : 1591 deleted records
# 2020-01-22
# Flux rep processed : 5441added records
# Flux rep modified new processed : 7366added records
# Flux rep partant processed : 2248 deleted records
# 2020-01-23
# Flux rep processed : 3383added records
# Flux rep modified new processed : 4684added records
# Flux rep partant processed : 1385 deleted records
# 2020-01-24
# Flux rep processed : 4887added records
# Flux rep modified new processed : 6998added records
# Flux rep partant processed : 1860 deleted records
# 2020-01-25
# 2020-01-26
# 2020-01-27
# Flux rep processed : 4439added records
# Flux rep modified new processed : 6386added records
# Flux rep partant processed : 1836 deleted records
# 2020-01-28
# Flux rep processed : 5369added records
# Flux rep modified new processed : 6703added records
# Flux rep partant processed : 1960 deleted records
# 2020-01-29
# Flux rep processed : 4630added records
# Flux rep modified new processed : 6802added records
# Flux rep partant processed : 2153 deleted records
# 2020-01-30
# Flux rep processed : 2592added records
# Flux rep modified new processed : 3766added records
# Flux rep partant processed : 1395 deleted records
# 2020-01-31
# Flux rep processed : 5908added records
# Flux rep modified new processed : 7906added records
# Flux rep partant processed : 2601 deleted records
# 2020-02-01
# Flux rep processed : 3841added records
# Flux rep modified new processed : 4761added records
# Flux rep partant processed : 1582 deleted records
# 2020-02-02
# 2020-02-03
# Flux rep processed : 318added records
# Flux rep modified new processed : 997added records
# Flux rep partant processed : 392 deleted records
# 2020-02-04
# Flux rep processed : 3727added records
# Flux rep modified new processed : 5749added records
# Flux rep partant processed : 1846 deleted records
# 2020-02-05
# Flux rep processed : 2800added records
# Flux rep modified new processed : 3618added records
# Flux rep partant processed : 1152 deleted records
# 2020-02-06
# Flux rep processed : 6715added records
# Flux rep modified new processed : 7554added records
# Flux rep partant processed : 2395 deleted records
# 2020-02-07
# Flux rep processed : 4719added records
# Flux rep modified new processed : 6428added records
# Flux rep partant processed : 1945 deleted records
# 2020-02-08
# Flux rep processed : 3841added records
# Flux rep modified new processed : 4758added records
# Flux rep partant processed : 1318 deleted records
# 2020-02-09
# 2020-02-10
# Flux rep processed : 299added records
# Flux rep modified new processed : 612added records
# Flux rep partant processed : 291 deleted records
# 2020-02-11
# Flux rep processed : 7099added records
# Flux rep modified new processed : 8106added records
# Flux rep partant processed : 2738 deleted records
# 2020-02-12
# Flux rep processed : 332added records
# Flux rep modified new processed : 748added records
# Flux rep partant processed : 368 deleted records
# 2020-02-13
# Flux rep processed : 492added records
# Flux rep modified new processed : 798added records
# Flux rep partant processed : 327 deleted records
# 2020-02-14
# Flux rep processed : 463added records
# Flux rep modified new processed : 729added records
# Flux rep partant processed : 322 deleted records
# 2020-02-15
# Flux rep processed : 15108added records
# Flux rep modified new processed : 19928added records
# Flux rep partant processed : 5879 deleted records
# 2020-02-16
# 2020-02-17
# Flux rep processed : 419added records
# Flux rep modified new processed : 804added records
# Flux rep partant processed : 323 deleted records
# 2020-02-18
# Flux rep processed : 3968added records
# Flux rep modified new processed : 5070added records
# Flux rep partant processed : 1659 deleted records
# 2020-02-19
# Flux rep processed : 4498added records
# Flux rep modified new processed : 6252added records
# Flux rep partant processed : 1802 deleted records
# 2020-02-20
# Flux rep processed : 5295added records
# Flux rep modified new processed : 7088added records
# Flux rep partant processed : 2433 deleted records
# 2020-02-21
# Flux rep processed : 3312added records
# Flux rep modified new processed : 5322added records
# Flux rep partant processed : 1676 deleted records
# 2020-02-22
# Flux rep processed : 5180added records
# Flux rep modified new processed : 6696added records
# Flux rep partant processed : 1735 deleted records
# 2020-02-23
# 2020-02-24
# Flux rep processed : 196added records
# Flux rep modified new processed : 868added records
# Flux rep partant processed : 484 deleted records
# 2020-02-25
# Flux rep processed : 5027added records
# Flux rep modified new processed : 6569added records
# Flux rep partant processed : 1972 deleted records
# 2020-02-26
# Flux rep processed : 3972added records
# Flux rep modified new processed : 5658added records
# Flux rep partant processed : 1684 deleted records
# 2020-02-27
# Flux rep processed : 2219added records
# Flux rep modified new processed : 3174added records
# Flux rep partant processed : 1168 deleted records
# 2020-02-28
# Flux rep processed : 6354added records
# Flux rep modified new processed : 7175added records
# Flux rep partant processed : 2001 deleted records
# 2020-02-29
# 2020-03-01
# 2020-03-02
# 2020-03-03
# loaded and uniformize
# Old stock
# Old Stock deleted : 193555 deleted records
# Stock processed : 114692added records
# 2020-03-04
# Flux rep processed : 17504added records
# Flux rep modified new processed : 18636added records
# Flux rep partant processed : 5650 deleted records
# 2020-03-05
# Flux rep processed : 4338added records
# Flux rep modified new processed : 5827added records
# Flux rep partant processed : 1816 deleted records
# 2020-03-06
# Flux rep processed : 1702added records
# Flux rep modified new processed : 2326added records
# Flux rep partant processed : 922 deleted records
# 2020-03-07
# Flux rep processed : 7013added records
# Flux rep modified new processed : 8181added records
# Flux rep partant processed : 2256 deleted records
# 2020-03-08
# 2020-03-09
# Flux rep processed : 317added records
# Flux rep modified new processed : 855added records
# Flux rep partant processed : 497 deleted records
# 2020-03-10
# Flux rep processed : 3379added records
# Flux rep modified new processed : 5367added records
# Flux rep partant processed : 1616 deleted records
# 2020-03-11
# Flux rep processed : 5202added records
# Flux rep modified new processed : 6858added records
# Flux rep partant processed : 2370 deleted records
# 2020-03-12
# Flux rep processed : 4375added records
# Flux rep modified new processed : 5160added records
# Flux rep partant processed : 1601 deleted records
# 2020-03-13
# Flux rep processed : 3275added records
# Flux rep modified new processed : 4165added records
# Flux rep partant processed : 1374 deleted records
# 2020-03-14
# Flux rep processed : 3551added records
# Flux rep modified new processed : 3984added records
# Flux rep partant processed : 1295 deleted records
# 2020-03-15
# 2020-03-16
# 2020-03-17
# Flux rep processed : 2792added records
# Flux rep modified new processed : 3524added records
# Flux rep partant processed : 1040 deleted records
# 2020-03-18
# Flux rep processed : 2233added records
# Flux rep modified new processed : 2125added records
# Flux rep partant processed : 732 deleted records
# 2020-03-19
# Flux rep processed : 1513added records
# Flux rep modified new processed : 2155added records
# Flux rep partant processed : 791 deleted records
# 2020-03-20
# Flux rep processed : 1471added records
# Flux rep modified new processed : 3861added records
# Flux rep partant processed : 1584 deleted records
# 2020-03-21
# Flux rep processed : 796added records
# Flux rep modified new processed : 1378added records
# Flux rep partant processed : 412 deleted records
# 2020-03-22
# 2020-03-23
# Flux rep processed : 328added records
# Flux rep modified new processed : 637added records
# Flux rep partant processed : 441 deleted records
# 2020-03-24
# Flux rep processed : 3650added records
# Flux rep modified new processed : 5467added records
# Flux rep partant processed : 1820 deleted records
# 2020-03-25
# Flux rep processed : 2491added records
# Flux rep modified new processed : 3386added records
# Flux rep partant processed : 1005 deleted records
# 2020-03-26
# Flux rep processed : 1867added records
# Flux rep modified new processed : 2620added records
# Flux rep partant processed : 1003 deleted records
# 2020-03-27
# Flux rep processed : 1936added records
# Flux rep modified new processed : 2567added records
# Flux rep partant processed : 914 deleted records
# 2020-03-28
# Flux rep processed : 1571added records
# Flux rep modified new processed : 2396added records
# Flux rep partant processed : 728 deleted records
# 2020-03-29
# 2020-03-30
# Flux rep processed : 190added records
# Flux rep modified new processed : 367added records
# Flux rep partant processed : 180 deleted records
# 2020-03-31
# Flux rep processed : 1948added records
# Flux rep modified new processed : 2623added records
# Flux rep partant processed : 899 deleted records
# 2020-04-01
# Flux rep processed : 1686added records
# Flux rep modified new processed : 2107added records
# Flux rep partant processed : 770 deleted records
# 2020-04-02
# Flux rep processed : 1923added records
# Flux rep modified new processed : 2448added records
# Flux rep partant processed : 848 deleted records
# 2020-04-03
# Flux rep processed : 2750added records
# Flux rep modified new processed : 3091added records
# Flux rep partant processed : 1002 deleted records
# 2020-04-04
# Flux rep processed : 1543added records
# Flux rep modified new processed : 2231added records
# Flux rep partant processed : 650 deleted records
# 2020-04-05
# 2020-04-06
# Flux rep processed : 202added records
# Flux rep modified new processed : 245added records
# Flux rep partant processed : 47 deleted records
# 2020-04-07
# Flux rep processed : 75added records
# Flux rep modified new processed : 235added records
# Flux rep partant processed : 138 deleted records
# 2020-04-08
# Flux rep processed : 2937added records
# Flux rep modified new processed : 3862added records
# Flux rep partant processed : 1312 deleted records
# 2020-04-09
# Flux rep processed : 2715added records
# Flux rep modified new processed : 3576added records
# Flux rep partant processed : 1219 deleted records
# 2020-04-10
# Flux rep processed : 1706added records
# Flux rep modified new processed : 2562added records
# Flux rep partant processed : 941 deleted records
# 2020-04-11
# Flux rep processed : 1402added records
# Flux rep modified new processed : 2018added records
# Flux rep partant processed : 529 deleted records
# 2020-04-12
# 2020-04-13
# Flux rep processed : 60added records
# Flux rep modified new processed : 0added records
# Flux rep partant processed : 0 deleted records
# 2020-04-14
# Flux rep processed : 330added records
# Flux rep modified new processed : 693added records
# Flux rep partant processed : 299 deleted records
# 2020-04-15
# Flux rep processed : 1295added records
# Flux rep modified new processed : 2348added records
# Flux rep partant processed : 831 deleted records
# 2020-04-16
# Flux rep processed : 1973added records
# Flux rep modified new processed : 2204added records
# Flux rep partant processed : 919 deleted records
# 2020-04-17
# Flux rep processed : 2541added records
# Flux rep modified new processed : 2157added records
# Flux rep partant processed : 651 deleted records
# 2020-04-18
# Flux rep processed : 1468added records
# Flux rep modified new processed : 2195added records
# ...
# Flux rep modified new processed : 3042added records
# Flux rep partant processed : 621 deleted records
# 2021-10-24
# 2021-10-25
# 2021-10-26
# Flux rep processed : 4970added records
# Flux rep modified new processed : 5051added records
# Flux rep partant processed : 1495 deleted records
# 2021-10-27
# Flux rep processed : 3977added records
# Flux rep modified new processed : 4178added records
# Flux rep partant processed : 1124 deleted records
# 2021-10-28
# Flux rep processed : 3936added records
# Flux rep modified new processed : 3933added records
# Flux rep partant processed : 773 deleted records
# 2021-10-29
# Flux rep processed : 4653added records
# Flux rep modified new processed : 3940added records
# Flux rep partant processed : 756 deleted records
# 2021-10-30
# Flux rep processed : 3741added records
# Flux rep modified new processed : 3455added records
# Flux rep partant processed : 662 deleted records
# 2021-10-31
# 2021-11-01
# 2021-11-02
# Flux rep processed : 715added records
# Flux rep modified new processed : 170added records
# Flux rep partant processed : 2 deleted records
# 2021-11-03
# Flux rep processed : 3998added records
# Flux rep modified new processed : 4649added records
# Flux rep partant processed : 1074 deleted records
# 2021-11-04
# Flux rep processed : 4003added records
# Flux rep modified new processed : 3738added records
# Flux rep partant processed : 885 deleted records
# 2021-11-05
# Flux rep processed : 4637added records
# Flux rep modified new processed : 4506added records
# Flux rep partant processed : 854 deleted records
# 2021-11-06
# Flux rep processed : 2935added records
# Flux rep modified new processed : 3483added records
# Flux rep partant processed : 815 deleted records
# 2021-11-07
# 2021-11-08
# 2021-11-09
# Flux rep processed : 5028added records
# Flux rep modified new processed : 5018added records
# Flux rep partant processed : 1125 deleted records
# 2021-11-10
# Flux rep processed : 3819added records
# Flux rep modified new processed : 4367added records
# Flux rep partant processed : 998 deleted records
# 2021-11-11
# Flux rep processed : 4108added records
# Flux rep modified new processed : 3435added records
# Flux rep partant processed : 678 deleted records
# 2021-11-12
# Flux rep processed : 1372added records
# Flux rep modified new processed : 651added records
# Flux rep partant processed : 215 deleted records
# 2021-11-13
# Flux rep processed : 3307added records
# Flux rep modified new processed : 2497added records
# Flux rep partant processed : 397 deleted records
# 2021-11-14
# 2021-11-15
# 2021-11-16
# Flux rep processed : 4537added records
# Flux rep modified new processed : 5183added records
# Flux rep partant processed : 1244 deleted records
# 2021-11-17
# Flux rep processed : 4953added records
# Flux rep modified new processed : 4533added records
# Flux rep partant processed : 974 deleted records
# 2021-11-18
# Flux rep processed : 4431added records
# Flux rep modified new processed : 4293added records
# Flux rep partant processed : 750 deleted records
# 2021-11-19
# Flux rep processed : 3343added records
# Flux rep modified new processed : 4433added records
# Flux rep partant processed : 955 deleted records
# 2021-11-20
# 2021-11-21
# 2021-11-22
# Flux rep processed : 2371added records
# Flux rep modified new processed : 2979added records
# Flux rep partant processed : 463 deleted records
# 2021-11-23
# loaded and uniformize
# Old stock
# Old Stock deleted : 228609 deleted records
# Stock processed : 115755added records
# 2021-11-24
# loaded and uniformize
# Old stock
# Old Stock deleted : 6623 deleted records
# Stock processed : 4209added records
# 2021-11-25
# Flux rep processed : 17090added records
# Flux rep modified new processed : 14433added records
# Flux rep partant processed : 2856 deleted records
# 2021-11-26
# Flux rep processed : 4357added records
# Flux rep modified new processed : 4507added records
# Flux rep partant processed : 927 deleted records
# 2021-11-27
# Flux rep processed : 3399added records
# Flux rep modified new processed : 2490added records
# Flux rep partant processed : 387 deleted records
# 2021-11-28
# 2021-11-29
# 2021-11-30
# Flux rep processed : 4976added records
# Flux rep modified new processed : 5636added records
# Flux rep partant processed : 1327 deleted records
# 2021-12-01
# Flux rep processed : 3881added records
# Flux rep modified new processed : 4571added records
# Flux rep partant processed : 885 deleted records
# 2021-12-02
# Flux rep processed : 4225added records
# Flux rep modified new processed : 4659added records
# Flux rep partant processed : 798 deleted records
# 2021-12-03
# Flux rep processed : 3550added records
# Flux rep modified new processed : 4158added records
# Flux rep partant processed : 911 deleted records
# 2021-12-04
# Flux rep processed : 3483added records
# Flux rep modified new processed : 3196added records
# Flux rep partant processed : 585 deleted records
# 2021-12-05
# 2021-12-06
# 2021-12-07
# Flux rep processed : 5550added records
# Flux rep modified new processed : 5007added records
# Flux rep partant processed : 991 deleted records
# 2021-12-08
# Flux rep processed : 4867added records
# Flux rep modified new processed : 4207added records
# Flux rep partant processed : 785 deleted records
# 2021-12-09
# Flux rep processed : 5333added records
# Flux rep modified new processed : 3800added records
# Flux rep partant processed : 805 deleted records
# 2021-12-10
# Flux rep processed : 5949added records
# Flux rep modified new processed : 4630added records
# Flux rep partant processed : 848 deleted records
# 2021-12-11
# Flux rep processed : 3277added records
# Flux rep modified new processed : 2695added records
# Flux rep partant processed : 513 deleted records
# 2021-12-12
# 2021-12-13
# loaded and uniformize
# Old stock
# Old Stock deleted : 4377 deleted records
# Stock processed : 3341added records
# 2021-12-14
# Flux rep processed : 6281added records
# Flux rep modified new processed : 5497added records
# Flux rep partant processed : 1081 deleted records
# 2021-12-15
# Flux rep processed : 4839added records
# Flux rep modified new processed : 4910added records
# Flux rep partant processed : 873 deleted records
# 2021-12-16
# Flux rep processed : 4989added records
# Flux rep modified new processed : 4375added records
# Flux rep partant processed : 721 deleted records
# 2021-12-17
# Flux rep processed : 4950added records
# Flux rep modified new processed : 4553added records
# Flux rep partant processed : 862 deleted records
# 2021-12-18
# Flux rep processed : 4579added records
# Flux rep modified new processed : 3589added records
# Flux rep partant processed : 523 deleted records
# 2021-12-19
# 2021-12-20
# 2021-12-21
# Flux rep processed : 5420added records
# Flux rep modified new processed : 4637added records
# Flux rep partant processed : 1043 deleted records
# 2021-12-22
# Flux rep processed : 4597added records
# Flux rep modified new processed : 4006added records
# Flux rep partant processed : 692 deleted records
# 2021-12-23
# Flux rep processed : 4393added records
# Flux rep modified new processed : 3674added records
# Flux rep partant processed : 521 deleted records
# 2021-12-24
# Flux rep processed : 4687added records
# Flux rep modified new processed : 3773added records
# Flux rep partant processed : 637 deleted records
# 2021-12-25
# Flux rep processed : 3117added records
# Flux rep modified new processed : 2015added records
# Flux rep partant processed : 402 deleted records
# 2021-12-26
# 2021-12-27
# 2021-12-28
# Flux rep processed : 3613added records
# Flux rep modified new processed : 4019added records
# Flux rep partant processed : 881 deleted records
# 2021-12-29
# Flux rep processed : 3122added records
# Flux rep modified new processed : 3704added records
# Flux rep partant processed : 699 deleted records
# 2021-12-30
# Flux rep processed : 3480added records
# Flux rep modified new processed : 3366added records
# Flux rep partant processed : 556 deleted records
# 2021-12-31
# Flux rep processed : 3200added records
# Flux rep modified new processed : 3362added records
# Flux rep partant processed : 639 deleted records
# 2022-01-01
# Flux rep processed : 1977added records
# Flux rep modified new processed : 2257added records
# Flux rep partant processed : 346 deleted records
# 2022-01-02
# 2022-01-03
# 2022-01-04
# Flux rep processed : 3237added records
# Flux rep modified new processed : 3936added records
# Flux rep partant processed : 943 deleted records
# 2022-01-05
# Flux rep processed : 3358added records
# Flux rep modified new processed : 4435added records
# Flux rep partant processed : 946 deleted records
# 2022-01-06
# Flux rep processed : 3362added records
# Flux rep modified new processed : 4118added records
# Flux rep partant processed : 860 deleted records
# 2022-01-07
# Flux rep processed : 3978added records
# Flux rep modified new processed : 3956added records
# Flux rep partant processed : 899 deleted records
# 2022-01-08
# Flux rep processed : 3582added records
# Flux rep modified new processed : 3156added records
# Flux rep partant processed : 566 deleted records
# 2022-01-09
# 2022-01-10
# 2022-01-11
# Flux rep processed : 4124added records
# Flux rep modified new processed : 4060added records
# Flux rep partant processed : 775 deleted records
# 2022-01-12
# Flux rep processed : 4231added records
# Flux rep modified new processed : 6307added records
# Flux rep partant processed : 1541 deleted records
# 2022-01-13
# Flux rep processed : 4102added records
# Flux rep modified new processed : 4349added records
# Flux rep partant processed : 850 deleted records
# 2022-01-14
# Flux rep processed : 4300added records
# Flux rep modified new processed : 4776added records
# Flux rep partant processed : 974 deleted records
# 2022-01-15
# Flux rep processed : 3798added records
# Flux rep modified new processed : 3992added records
# Flux rep partant processed : 686 deleted records
# 2022-01-16
# 2022-01-17
# 2022-01-18
# Flux rep processed : 4889added records
# Flux rep modified new processed : 5540added records
# Flux rep partant processed : 977 deleted records
# 2022-01-19
# Flux rep processed : 4199added records
# Flux rep modified new processed : 5714added records
# Flux rep partant processed : 1081 deleted records
# 2022-01-20
# Flux rep processed : 3847added records
# Flux rep modified new processed : 5008added records
# Flux rep partant processed : 1800 deleted records
# 2022-01-21
# Flux rep processed : 4253added records
# Flux rep modified new processed : 5529added records
# Flux rep partant processed : 1888 deleted records
# 2022-01-22
# Flux rep processed : 4446added records
# Flux rep modified new processed : 4341added records
# Flux rep partant processed : 1600 deleted records
# 2022-01-23
# 2022-01-24
# 2022-01-25
# loaded and uniformize
# Old stock
# Old Stock deleted : 364323 deleted records
# Stock processed : 168743added records
# 2022-01-26
# Flux rep processed : 9293added records
# Flux rep modified new processed : 11062added records
# Flux rep partant processed : 3922 deleted records
# 2022-01-27
# Flux rep processed : 4211added records
# Flux rep modified new processed : 4911added records
# Flux rep partant processed : 1782 deleted records
# 2022-01-28
# Flux rep processed : 4367added records
# Flux rep modified new processed : 5206added records
# Flux rep partant processed : 1975 deleted records
# 2022-01-29
# Flux rep processed : 3538added records
# Flux rep modified new processed : 4555added records
# Flux rep partant processed : 2218 deleted records
# 2022-01-30
# 2022-01-31
# 2022-02-01
# loaded and uniformize
# Old stock
# Old Stock deleted : 248322 deleted records
# Stock processed : 154770added records
# 2022-02-02
# Flux rep processed : 10100added records
# Flux rep modified new processed : 10936added records
# Flux rep partant processed : 3864 deleted records
# 2022-02-03
# Flux rep processed : 2477added records
# Flux rep modified new processed : 4596added records
# Flux rep partant processed : 1837 deleted records
# 2022-02-04
# Flux rep processed : 4420added records
# Flux rep modified new processed : 5224added records
# Flux rep partant processed : 1894 deleted records
# 2022-02-05
# Flux rep processed : 5265added records
# Flux rep modified new processed : 3954added records
# Flux rep partant processed : 1704 deleted records
# 2022-02-06
# 2022-02-07
# 2022-02-08
# Flux rep processed : 5387added records
# Flux rep modified new processed : 5754added records
# Flux rep partant processed : 2055 deleted records
# 2022-02-09
# Flux rep processed : 4186added records
# Flux rep modified new processed : 5377added records
# Flux rep partant processed : 2038 deleted records
# 2022-02-10
# Flux rep processed : 4179added records
# Flux rep modified new processed : 4654added records
# Flux rep partant processed : 1714 deleted records
# 2022-02-11
# Flux rep processed : 4684added records
# Flux rep modified new processed : 5235added records
# Flux rep partant processed : 1911 deleted records
# 2022-02-12
# Flux rep processed : 3830added records
# Flux rep modified new processed : 4134added records
# Flux rep partant processed : 908 deleted records
# 2022-02-13
# 2022-02-14
# 2022-02-15
# Flux rep processed : 5300added records
# Flux rep modified new processed : 5657added records
# Flux rep partant processed : 1134 deleted records
# 2022-02-16
# Flux rep processed : 4364added records
# Flux rep modified new processed : 5351added records
# Flux rep partant processed : 902 deleted records
# 2022-02-17
# Flux rep processed : 4586added records
# Flux rep modified new processed : 4882added records
# Flux rep partant processed : 1040 deleted records
# 2022-02-18
# Flux rep processed : 4319added records
# Flux rep modified new processed : 5314added records
# Flux rep partant processed : 963 deleted records
# 2022-02-19
# Flux rep processed : 3810added records
# Flux rep modified new processed : 3955added records
# Flux rep partant processed : 788 deleted records
# 2022-02-20
# 2022-02-21
# 2022-02-22
# Flux rep processed : 4952added records
# Flux rep modified new processed : 6289added records
# Flux rep partant processed : 1397 deleted records
# 2022-02-23
# Flux rep processed : 4427added records
# Flux rep modified new processed : 5404added records
# Flux rep partant processed : 1065 deleted records
# 2022-02-24
# Flux rep processed : 4112added records
# Flux rep modified new processed : 5193added records
# Flux rep partant processed : 1031 deleted records
# 2022-02-25
# Flux rep processed : 4262added records
# Flux rep modified new processed : 4785added records
# Flux rep partant processed : 913 deleted records
# 2022-02-26
# Flux rep processed : 3575added records
# Flux rep modified new processed : 3502added records
# Flux rep partant processed : 560 deleted records
# 2022-02-27
# 2022-02-28
# 2022-03-01
# loaded and uniformize
# Old stock
# Old Stock deleted : 135182 deleted records
# Stock processed : 69503added records
# 2022-03-02
# 2022-03-03
# Flux rep processed : 13477added records
# Flux rep modified new processed : 16153added records
# Flux rep partant processed : 3011 deleted records
# 2022-03-04
# Flux rep processed : 4180added records
# Flux rep modified new processed : 4911added records
# Flux rep partant processed : 982 deleted records
# 2022-03-05
# Flux rep processed : 3408added records
# Flux rep modified new processed : 3995added records
# Flux rep partant processed : 619 deleted records
# 2022-03-06
# 2022-03-07
# 2022-03-08
# Flux rep processed : 5412added records
# Flux rep modified new processed : 5644added records
# Flux rep partant processed : 1119 deleted records
# 2022-03-09
# Flux rep processed : 4485added records
# Flux rep modified new processed : 5419added records
# Flux rep partant processed : 906 deleted records
# 2022-03-10
# Flux rep processed : 3984added records
# Flux rep modified new processed : 3998added records
# Flux rep partant processed : 609 deleted records
# 2022-03-11
# Flux rep processed : 3723added records
# Flux rep modified new processed : 4512added records
# Flux rep partant processed : 604 deleted records
# 2022-03-12
# Flux rep processed : 4238added records
# Flux rep modified new processed : 4475added records
# Flux rep partant processed : 706 deleted records
# 2022-03-13
# 2022-03-14
# Flux rep processed : 621added records
# Flux rep modified new processed : 943added records
# Flux rep partant processed : 499 deleted records
# 2022-03-15
# Flux rep processed : 5344added records
# Flux rep modified new processed : 5792added records
# Flux rep partant processed : 1017 deleted records
# 2022-03-16
# Flux rep processed : 4329added records
# Flux rep modified new processed : 5221added records
# Flux rep partant processed : 910 deleted records

# %%
conn = sqlite3.connect('inpi.db', isolation_level=None,
                       detect_types=sqlite3.PARSE_COLNAMES)
print('connected')

db = pd.read_sql_query("SELECT * FROM rep_pm", conn)
print('read rep_pm ok')
db = db.drop_duplicates(keep="first")
print('deduplicates ok')
dbpm = db.groupby(['siren','rep_denomination'],as_index=False)['rep_qualite'].agg(lambda col: ', '.join(col))
print('groupby ok')
dbpm[dbpm['siren'] != ''].to_csv('rep_pm.csv',index=False)
print('csv saved ok')

db = pd.read_sql_query("SELECT * FROM rep_pp", conn)
print('read rep_pp ok')
db = db.drop_duplicates(keep="first")
print('deduplicates ok')
dbpp = db.groupby(['siren','rep_noms','rep_prenoms'],as_index=False)['rep_qualite'].agg(lambda col: ', '.join(col))
print('groupby ok')
dbpp[dbpp['siren'] != ''].to_csv('rep_pp.csv',index=False)
print('csv saved ok')
